# %%
import requests
import json
import xmltodict
import pandas as pd
serviceKey = 'SDEjyCFJI1ki5hZaMAvBGUsre6U38rZKkVug%2BDGju9aAUp9G7%2B1tQagaeWcG2trJmx1%2BXe0JANCSgpGnLFuOPA%3D%3D'
pageNo = 1 # 페이지 번호
numOfRows = 1000 # 한 페이지 결과수
LAWD_CD = 11560 # 지역코드
DEAL_YMD = 202304 # 계약월
url = f'http://openapi.molit.go.kr/OpenAPI_ToolInstallPackage/service/rest/RTMSOBJSvc/getRTMSDataSvcAptTradeDev?serviceKey={serviceKey}&pageNo={pageNo}&numOfRows=10&LAWD_CD={LAWD_CD}&DEAL_YMD={DEAL_YMD}'
req = requests.get(url)
req
# Out:
# <Response [200]>

# %%
req.text
# Out:
# '<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>00</resultCode><resultMsg>NORMAL SERVICE.</resultMsg></header><body><items><item><거래금액>    96,000</거래금액><거래유형>중개거래</거래유형><건축년도>2002</건축년도><년>2023</년><도로명>도신로29길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154317</도로명코드><법정동> 영등포동</법정동><법정동본번코드>0647</법정동본번코드><법정동부번코드>0000</법정동부번코드><법정동시군구코드>11560</법정동시군구코드><법정동읍면동코드>10100</법정동읍면동코드><법정동지번코드>1</법정동지번코드><아파트>영등포푸르지오</아파트><월>4</월><일>6</일><일련번호>11560-2</일련번호><전용면적>79.777</전용면적><중개사소재지>서울 영등포구</중개사소재지><지번>647</지번><지역코드>11560</지역코드><층>17</층><해제사유발생일> </해제사유발생일><해제여부> </해제여부></item><item><거래금액>    92,500</거래금액><거래유형>중개거래</거래유형><건축년도>2002</건축년도><년>2023</년><도로명>도신로29길</도로명><도로명건물본번호코드>00028</도로명건물본번호코드><도로명건물부번호코드>00000</도로명건물부번호코드><도로명시군구코드>11560</도로명시군구코드><도로명일련번호코드>01</도로명일련번호코드><도로명지상지하코드>0</도로명지상지하코드><도로명코드>4154317</도로명코드><법정동> 영등포동</법정동><법정동본번코드>0647<
# ...

# %%
contents = xmltodict.parse(req.text) # XML을 json으로 변환
contents
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '96,000',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154317',
#       '법정동': '영등포동',
#       '법정동본번코드': '0647',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '영등포푸르지오',
#       '월': '4',
#       '일': '6',
#       '일련번호': '11560-2',
#       '전용면적': '79.777',
#       '중개사소재지': '서울 영등포구',
#       '지번': '647',
#       '지역코드': '11560',
#       '층': '17',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '92,500',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
# ...

# %%
type(json_df)
# Out:
# str

# %%
dict_df = json.loads(json_df)
dict_df
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': 'NORMAL SERVICE.'},
#   'body': {'items': {'item': [{'거래금액': '96,000',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
#       '도로명시군구코드': '11560',
#       '도로명일련번호코드': '01',
#       '도로명지상지하코드': '0',
#       '도로명코드': '4154317',
#       '법정동': '영등포동',
#       '법정동본번코드': '0647',
#       '법정동부번코드': '0000',
#       '법정동시군구코드': '11560',
#       '법정동읍면동코드': '10100',
#       '법정동지번코드': '1',
#       '아파트': '영등포푸르지오',
#       '월': '4',
#       '일': '6',
#       '일련번호': '11560-2',
#       '전용면적': '79.777',
#       '중개사소재지': '서울 영등포구',
#       '지번': '647',
#       '지역코드': '11560',
#       '층': '17',
#       '해제사유발생일': None,
#       '해제여부': None},
#      {'거래금액': '92,500',
#       '거래유형': '중개거래',
#       '건축년도': '2002',
#       '년': '2023',
#       '도로명': '도신로29길',
#       '도로명건물본번호코드': '00028',
#       '도로명건물부번호코드': '00000',
# ...

# %%
type(dict_df)
# Out:
# dict

# %%
data = pd.DataFrame(dict_df['response']['body']['items']['item'])
data
# Out:
#      거래금액  거래유형  건축년도     년      도로명 도로명건물본번호코드 도로명건물부번호코드 도로명시군구코드 도로명일련번호코드  \
# 0  96,000  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 1  92,500  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 2  84,000  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 3  96,500  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 4  89,000  중개거래  2002  2023   도신로29길      00028      00000    11560        01
# 5  89,000   직거래  2002  2023   도신로29길      00028      00000    11560        01
# 6  12,000  중개거래  2012  2023  경인로114길      00012      00000    11560        01
# 7  21,000   직거래  2020  2023      경인로      00900      00000    11560        00
# 8  37,800   직거래  2022  2023    버드나루로      00005      00000    11560        00
# 9  10,350  중개거래  2014  2023    영중로6길      00012      00000    11560        01
#
#   도로명지상지하코드  ...  월   일        일련번호     전용면적   중개사소재지    지번   지역코드   층  \
# ...
