# %% [markdown]
# ## series, dataframe

# %%
import pandas as pd 

d = {'a': 1, 'b': 2, 'c': 3}
ser = pd.Series(data=d, index=['a', 'b', 'c'])
ser
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
import pandas as pd 

d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)
print(df)
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd 

df_boston = pd.read_csv("./data/boston.csv")
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %%
import pandas as pd 

df_boston = pd.read_csv("./data/boston.csv")
df_boston
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  target
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# ## 열 선택

# %%
cols = ['CRIM', 'ZN', 'INDUS']
result = df_boston[cols].head()
print(result)
# Out:
#       CRIM    ZN  INDUS
# 0  0.00632  18.0   2.31
# 1  0.02731   0.0   7.07
# 2  0.02729   0.0   7.07
# 3  0.03237   0.0   2.18
# 4  0.06905   0.0   2.18

# %% [markdown]
# ## 행 선택

# %%
result = df_boston[df_boston['ZN'] == 18.0]
cols = ['CRIM', 'ZN', 'INDUS']
print(result[cols])
# Out:
#       CRIM    ZN  INDUS
# 0  0.00632  18.0   2.31

# %% [markdown]
# ## .loc와 iloc

# %%
df_boston.loc['CRI']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 df_boston.loc['CRI']
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexing.py:1312, in _LocIndexer._getitem_axis(self, key, axis)
#    1310 # fall thru to straight lookup
#    1311 self._validate_key(key, axis)
# -> 1312 return self._get_label(key, axis=axis)
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexing.py:1260, in _LocIndexer._get_label(self, label, axis)
#    1258 def _get_label(self, label, axis: int):
#    1259     # GH#5567 this will fail if the label is not present in the axis.
# -> 1260     return self.obj.xs(label, axis=axis)
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\generic.py:4056, in NDFrame.xs(self, key, axis, level, drop_level)
#    4054             new_index = index[loc]
#    4055 else:
# -> 4056     loc = index.get_loc(key)
#    4058     if isinstance(loc, np.ndarray):
#    4059         if loc.dtype == np.bool_:
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexes\range.py:395, in RangeIndex.get_loc(self, key, method, tolerance)
#     393             raise KeyError(key) from err
#     394     self._check_indexing_error(key)
# --> 395     raise KeyError(key)
#     396 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: 'CRI'

# %%
df_boston.iloc[:, 20]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 df_boston.iloc[:, 20]
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     871 for i, k in enumerate(key):
#     872     try:
# --> 873         self._validate_key(k, i)
#     874     except ValueError as err:
#     875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexing.py:1466, in _iLocIndexer._validate_key(self, key, axis)
#    1464     return
#    1465 elif is_integer(key):
# -> 1466     self._validate_integer(key, axis)
#    1467 elif isinstance(key, tuple):
#    1468     # a tuple should already have been caught by this point
#    1469     # so don't treat a tuple as a valid indexer
#    1470     raise IndexingError("Too many indexers")
#
# File ~\Desktop\streamlitbook-evansarah\venv\Lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# ### loc

# %%
cols = ['CRIM', 'ZN', 'target']
result = df_boston.loc[df_boston['CRIM'] < 1, cols]
print(result.head(3))

# %%
cols = ['CRIM', 'ZN', 'target']
result = df_boston.loc[(df_boston['CRIM'] < 1) &\
                       (df_boston['target'] >= 24.0), cols]
print(result.head(3))

# %%
cols = ['CRIM', 'ZN', 'target']
result = df_boston.loc[(df_boston['CRIM'] < 1) |\
                       (df_boston['target'] >= 24.0), cols]
print(result.head(3))

# %% [markdown]
# ### iloc

# %%
result = df_boston.iloc[0:5, 0:3]
print(result)

# %%
result = df_boston.iloc[20, 0:3]
print(result)
print(type(result))

# %% [markdown]
# ## describe()

# %%
cols = ['CRIM', 'ZN', 'target']
print(df_boston[cols].describe())

# %% [markdown]
# ## rename

# %%
sample_df = df_boston.iloc[:, 0:4]
sample_df.head()

# %%
sample_df = sample_df.rename(columns={'ZN': 'landZone'})
sample_df.head()

# %%
sample_df = sample_df.rename(columns={'CRIM': 'crime', 
                                      'INDUS':'businessRatio'})
sample_df.head()

# %% [markdown]
# ## value_counts()

# %%
df_boston['RAD'].value_counts()
# Out:
# 24.0    132
# 5.0     115
# 4.0     110
# 3.0      38
# 6.0      26
# 2.0      24
# 8.0      24
# 1.0      20
# 7.0      17
# Name: RAD, dtype: int64

# %%
type(df_boston['RAD'].value_counts())
# Out:
# pandas.core.series.Series

# %%
df_boston['RAD'].value_counts(normalize=True)
# Out:
# 24.0    0.260870
# 5.0     0.227273
# 4.0     0.217391
# 3.0     0.075099
# 6.0     0.051383
# 2.0     0.047431
# 8.0     0.047431
# 1.0     0.039526
# 7.0     0.033597
# Name: RAD, dtype: float64

# %%
df_boston['RAD'].value_counts(normalize=True)
# Out:
# 24.0    0.260870
# 5.0     0.227273
# 4.0     0.217391
# 3.0     0.075099
# 6.0     0.051383
# 2.0     0.047431
# 8.0     0.047431
# 1.0     0.039526
# 7.0     0.033597
# Name: RAD, dtype: float64

# %%
import pandas as pd

df = pd.DataFrame({'시군구': ['관악구', '서대문구', '강남구', '서초구'],
                   '부동산가격': [10000, 20000, 30000, 40000]})

cities = ['관악구', '서대문구']
filtered_df = df[df['시군구'].isin(cities)]

filtered_df
# Out:
#     시군구  부동산가격
# 0   관악구  10000
# 1  서대문구  20000

# %%
numbers = [1.0, 7.0]
filtered_df = df_boston[df_boston['RAD'].isin(numbers)]
filtered_df[['CRIM', 'RAD']].head(6)
# Out:
#         CRIM  RAD
# 0    0.00632  1.0
# 193  0.02187  1.0
# 194  0.01439  1.0
# 244  0.20608  7.0
# 245  0.19133  7.0
# 246  0.33983  7.0

# %% [markdown]
# ## Time Series

# %%
date_string = '2023-03-02'
datetime_obj = pd.to_datetime(date_string)
print(datetime_obj)
print(type(datetime_obj))
# Out:
# 2023-03-02 00:00:00
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
date_list = ['2023-03-02']
datetime_obj_list = pd.to_datetime(date_list)
print(datetime_obj_list)
print(type(datetime_obj_list))
# Out:
# DatetimeIndex(['2023-03-02'], dtype='datetime64[ns]', freq=None)
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
sales = pd.read_csv('data/raw_sales.csv')
sales.head(3)
# Out:
#               datesold  postcode   price propertyType  bedrooms
# 0  2007-02-07 00:00:00      2607  525000        house         4
# 1  2007-02-27 00:00:00      2906  290000        house         3
# 2  2007-03-07 00:00:00      2905  328000        house         3

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29580 entries, 0 to 29579
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datesold      29580 non-null  object
#  1   postcode      29580 non-null  int64
#  2   price         29580 non-null  int64
#  3   propertyType  29580 non-null  object
#  4   bedrooms      29580 non-null  int64
# dtypes: int64(3), object(2)
# memory usage: 1.1+ MB

# %%
sales['datesold'] = pd.to_datetime(sales['datesold'])
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29580 entries, 0 to 29579
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datesold      29580 non-null  datetime64[ns]
#  1   postcode      29580 non-null  int64
#  2   price         29580 non-null  int64
#  3   propertyType  29580 non-null  object
#  4   bedrooms      29580 non-null  int64
# dtypes: datetime64[ns](1), int64(3), object(1)
# memory usage: 1.1+ MB

# %%
sales["datesold"].max() - sales["datesold"].min()
# Out:
# Timedelta('4553 days 00:00:00')

# %%
sales["year"] = sales["datesold"].dt.year
sales["month"] = sales["datesold"].dt.month
sales["day"] = sales["datesold"].dt.day

sales.head()
# Out:
#     datesold  postcode   price propertyType  bedrooms  year  month  day
# 0 2007-02-07      2607  525000        house         4  2007      2    7
# 1 2007-02-27      2906  290000        house         3  2007      2   27
# 2 2007-03-07      2905  328000        house         3  2007      3    7
# 3 2007-03-09      2905  380000        house         4  2007      3    9
# 4 2007-03-21      2906  310000        house         3  2007      3   21

# %% [markdown]
# ## shift

# %%
temp_df = sales[['datesold', 'price']].copy()
temp_df['shifted_v1'] = temp_df['price'].shift(1, fill_value=0).astype(int)
temp_df['shifted_v2'] = temp_df['price'].shift(2, fill_value=0).astype(int)
temp_df.head()
# Out:
#     datesold   price  shifted_v1  shifted_v2
# 0 2007-02-07  525000           0           0
# 1 2007-02-27  290000      525000           0
# 2 2007-03-07  328000      290000      525000
# 3 2007-03-09  380000      328000      290000
# 4 2007-03-21  310000      380000      328000

# %%
temp_df['shifted_v3'] = temp_df['price'].shift(-1, fill_value=0).astype(int)
temp_df['shifted_v4'] = temp_df['price'].shift(-2, fill_value=0).astype(int)
temp_df.tail()
# Out:
#         datesold   price  shifted_v1  shifted_v2  shifted_v3  shifted_v4
# 29575 2019-07-25  500000      475000      380000      560000      464950
# 29576 2019-07-25  560000      500000      475000      464950      589000
# 29577 2019-07-26  464950      560000      500000      589000      775000
# 29578 2019-07-26  589000      464950      560000      775000           0
# 29579 2019-07-26  775000      589000      464950           0           0

# %%
temp_df['한글날짜'] = temp_df['datesold'].dt.strftime("%Y년 %m월 %d일")
temp_df.head()
# Out:
#     datesold   price  shifted_v1  shifted_v2  shifted_v3  shifted_v4  \
# 0 2007-02-07  525000           0           0      290000      328000
# 1 2007-02-27  290000      525000           0      328000      380000
# 2 2007-03-07  328000      290000      525000      380000      310000
# 3 2007-03-09  380000      328000      290000      310000      465000
# 4 2007-03-21  310000      380000      328000      465000      399000
#
#             한글날짜
# 0  2007년 02월 07일
# 1  2007년 02월 27일
# 2  2007년 03월 07일
# 3  2007년 03월 09일
# 4  2007년 03월 21일

# %% [markdown]
# ## GroupBy 연산
# - raw_sales

# %%
import pandas as pd 

sales = pd.read_csv('data/raw_sales.csv')
sales.head()
# Out:
#               datesold  postcode   price propertyType  bedrooms
# 0  2007-02-07 00:00:00      2607  525000        house         4
# 1  2007-02-27 00:00:00      2906  290000        house         3
# 2  2007-03-07 00:00:00      2905  328000        house         3
# 3  2007-03-09 00:00:00      2905  380000        house         4
# 4  2007-03-21 00:00:00      2906  310000        house         3

# %%
agg_dict = {"price" : "mean", "bedrooms" : "mean"}
grouped = sales.groupby("propertyType").agg(agg_dict)
grouped
# Out:
#                       price  bedrooms
# propertyType
# house         647956.128462  3.539467
# unit          423106.557279  1.837510

# %%
grouped.reset_index()
# Out:
#   propertyType          price  bedrooms
# 0        house  647956.128462  3.539467
# 1         unit  423106.557279  1.837510

# %%
agg_dict = {"price" : ["sum", "median"], "bedrooms" : "mean"}
grouped = sales.groupby("propertyType").agg(agg_dict)
grouped
# Out:
#                     price            bedrooms
#                       sum    median      mean
# propertyType
# house         15908618866  585000.0  3.539467
# unit           2127379770  390000.0  1.837510

# %%
grouped.columns
# Out:
# MultiIndex([(   'price',    'sum'),
#             (   'price', 'median'),
#             ('bedrooms',   'mean')],
#            )

# %%
new_columns = []
for col in grouped.columns:
    if isinstance(col, tuple):
        new_col = f'{col[0]}_{col[1]}'
    else:
        new_col = col
    new_columns.append(new_col)

grouped.columns = new_columns
grouped
# Out:
#                 price_sum  price_median  bedrooms_mean
# propertyType
# house         15908618866      585000.0       3.539467
# unit           2127379770      390000.0       1.837510

# %%
sales['datesold'] = pd.to_datetime(sales['datesold'])
sales["year"] = sales["datesold"].dt.year
sales["month"] = sales["datesold"].dt.month
sales["day"] = sales["datesold"].dt.day
sales.head()
# Out:
#     datesold  postcode   price propertyType  bedrooms  year  month  day
# 0 2007-02-07      2607  525000        house         4  2007      2    7
# 1 2007-02-27      2906  290000        house         3  2007      2   27
# 2 2007-03-07      2905  328000        house         3  2007      3    7
# 3 2007-03-09      2905  380000        house         4  2007      3    9
# 4 2007-03-21      2906  310000        house         3  2007      3   21
